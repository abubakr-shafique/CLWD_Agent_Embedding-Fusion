# %% [markdown]
# ## HF Login

# %%
from huggingface_hub import login

hf_token = "" ## Enter Your HF Access Token
login(token=hf_token)
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.

# %% [markdown]
# ## Lung_Pathology_Image_JPG

# %%
from huggingface_hub import snapshot_download
import os
import project_dirs as pdir

repo_id = "kmmuleelab/Lung_Pathology_Image_JPG" # Replace with your repo ID
local_dir = pdir.DATA_JPG_DIR    # Replace with your desired local directory
os.makedirs(local_dir, exist_ok=True)

# # This downloads the entire repository folder structure
snapshot_download(repo_id=repo_id, repo_type="dataset", local_dir=local_dir)
